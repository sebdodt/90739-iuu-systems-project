# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sns.set_style('white')
sns.set_context("paper", font_scale = 1)
color = sns.color_palette("tab10", 10)[0]

# %%
data = pd.read_excel('/Users/sebastiandodt/OneDrive/Uni/Carnegie Mellon University/Modules/2022 Fall/Systems Project/Coding/90739-iuu-systems-project/port_evaluation/data/input/Bikash analysis/Port_State_Data_New.xlsx',
    sheet_name='Sheet2')

# %%
data['log GDP'] = np.log(data['GDP '])
data['log GDP per capita'] = np.log(data['GDP Per Capita'])
sns.scatterplot(data, x='log GDP per capita', y='EEZ KM2', hue='CPI score 2021')
plt.savefig('plot.png', dpi=600)
plt.show()

# %%
data['log GDP'] = np.log(data['GDP '])
data['log GDP per capita'] = np.log(data['GDP Per Capita'])
data['log EEZ size'] = np.log(data['EEZ KM2'])

sns.FacetGrid(data, hue="CPI score 2021") \
   .map(plt.scatter, "log GDP per capita", "log EEZ size") #\
   # .add_legend()
sns.regplot(x="log GDP per capita", y="log EEZ size", data=data, ci=False)



# sns.regplot(data, x='log GDP', y='log EEZ size', )
plt.savefig('loglog.png', dpi=600)
plt.show()
# Out:
# /Users/sebastiandodt/opt/miniconda3/envs/capstoneenv/lib/python3.10/site-packages/seaborn/axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# /Users/sebastiandodt/opt/miniconda3/envs/capstoneenv/lib/python3.10/site-packages/seaborn/axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# /Users/sebastiandodt/opt/miniconda3/envs/capstoneenv/lib/python3.10/site-packages/seaborn/axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# /Users/sebastiandodt/opt/miniconda3/envs/capstoneenv/lib/python3.10/site-packages/seaborn/axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# ...

# %%
data['log GDP'] = np.log(data['GDP '])
data['log GDP per capita'] = np.log(data['GDP Per Capita'])
data['log EEZ size'] = np.log(data['EEZ KM2'])
sns.scatterplot(data, x='log EEZ size', y='CPI score 2021', hue='log GDP per capita')
plt.savefig('flipped_axes_2.png', dpi=600)
plt.show()
