# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/sebastiandodt/OneDrive/Uni/Carnegie Mellon University/Modules/2022 Fall/Systems Project/Coding/90739-iuu-systems-project/port_evaluation/data/proc/labels/classified_carriers_v1.csv')

# %%
df['share_of_loitering'] = df['loitering']/(df['encounter']+df['loitering'])
df['more_than_100_encounters'] = df['loitering'] + df['encounter'] > 100

# %%
sns.histplot(data = df, x = 'share_of_loitering')
plt.xlabel('Share of reefers meet-ups without transponder')
plt.show()

# %%
df_filtered = df.loc[df['more_than_100_encounters'] == 1,:]
sns.histplot(data = df_filtered, x = 'share_of_loitering')
plt.xlabel('Share of meet-ups without transponder')
plt.title('Carriers with more then 100 meet ups')
plt.show()

# %%
path = '/Users/sebastiandodt/OneDrive/Uni/Carnegie Mellon University/Modules/2022 Fall/Systems Project/Coding/90739-iuu-systems-project/port_evaluation/data/xlsx/gfw_data-v2.xlsx'
port_visits = pd.read_excel(path, sheet_name='carrier_port_visit-v2')
port_visits.head()
# Out:
#                                  id  type                    start  \
# 0  af03d0b85979b8c91ae5ea165d0fd2e0  port  2012-10-24 12:21:05 UTC
# 1  76c123fc888c38f8424d444308e74739  port  2012-10-24 10:00:48 UTC
# 2  a3910ba2f8e734f7343fe2c3886e031a  port  2012-10-24 23:02:21 UTC
# 3  c3bf496236204dead751072c35d5fefc  port  2012-10-24 14:57:38 UTC
# 4  ef23a729101f8d93679a51697754c7c3  port  2012-10-24 07:15:58 UTC
#
#                        end        lat         lon  \
# 0  2012-10-24 21:07:44 UTC  18.460661  -66.111945
# 1  2012-10-26 14:49:48 UTC   8.024300  -76.780133
# 2  2012-10-25 16:23:59 UTC  62.777300    6.917326
# 3  2012-10-25 16:49:53 UTC -16.990203  -72.142333
# 4  2012-10-25 09:39:17 UTC  52.874624  158.663179
#
#                                vessel.id vessel.type  vessel.mmsi  \
# 0  3fe8729f8-80c4-2d9b-70cb-02aa09353f4e     carrier    311295000
# 1  b3089e7df-fd55-d6e8-2292-e7bb093023fe     carrier    308090000
# 2  1c3ee5f35-5189-56ac-07a5-a99a6624b7aa     carrier    311411000
# 3  65032eb47-732f-946e-ea32-03567b0cefd8     carrier    636011106
# 4  6fc826893-3007-30a2-8cb3-dea6f5087bc0     carrier    273845620
#
#           vessel.name  ...  \
# 0           DOLE ASIA  ...
# 1       HELLAS STREAM  ...
# 2         SAMSKIP ICE  ...
# 3        BALTIC PRIDE  ...
# 4  POGRANICHNIK_ZMEEV  ...
#
#   encounter.encountered_vessel.destination_port.country  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    encounter.encountered_vessel.destination_port.name  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    encounter.encountered_vessel.authorizations.authorized  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    encounter.encountered_vessel.authorizations.unknown  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    loitering.total_distance_km  loitering.loitering_hours   port.lat  \
# 0                          NaN                        NaN  18.460661
# 1                          NaN                        NaN   8.024300
# 2                          NaN                        NaN  62.777300
# 3                          NaN                        NaN -16.990203
# 4                          NaN                        NaN  52.874624
#
#      port.lon  port.country      port.name
# 0  -66.111945           PRI       SAN JUAN
# 1  -76.780133           COL          TURBO
# 2    6.917326           NOR            NaN
# 3  -72.142333           PER       MATARANI
# 4  158.663179           RUS  PETROPAVLOVSK
#
# [5 rows x 41 columns]

# %%
port_visits.columns
# Out:
# Index(['id', 'type', 'start', 'end', 'lat', 'lon', 'vessel.id', 'vessel.type',
#        'vessel.mmsi', 'vessel.name', 'vessel.flag',
#        'vessel.origin_port.country', 'vessel.origin_port.name',
#        'vessel.destination_port.country', 'vessel.destination_port.name',
#        'vessel.authorizations.authorized', 'vessel.authorizations.unknown',
#        'median_speed_knots', 'elevation_m', 'distance_from_shore_m',
#        'distance_from_port_m', 'regions.rfmo', 'encounter.median_distance_km',
#        'encounter.authorization_status', 'encounter.encountered_vessel.id',
#        'encounter.encountered_vessel.type',
#        'encounter.encountered_vessel.mmsi',
#        'encounter.encountered_vessel.name',
#        'encounter.encountered_vessel.flag',
#        'encounter.encountered_vessel.origin_port.country',
#        'encounter.encountered_vessel.origin_port.name',
#        'encounter.encountered_vessel.destination_port.country',
#        'encounter.encountered_vessel.destination_port.name',
#        'encounter.encountered_vessel.authorizations.authorized',
#        'encounter.encountered_vessel.authorizations.unknown',
#        'loitering.total_distance_km', 'loitering.loitering_hours', 'port.lat',
#        'port.lon', 'port.country', 'port.name'],
#       dtype='object')

# %%
vessels = df['id'].unique()
port_visits_known_ships = port_visits.loc[port_visits['vessel.id'].isin(vessels), :]
len(port_visits_known_ships)
# Out:
# 382472

# %%
port_vessel_count = port_visits_known_ships.groupby(['port.name', 'vessel.id'])['id'].count().reset_index()
port_vessel_with_label = port_vessel_count.merge(df, how='left', left_on='vessel.id', right_on='id', suffixes=('_port', '_carrier'))
share_of_loitering = port_vessel_with_label.groupby('port.name')['share_of_loitering'].mean().reset_index()
number_of_bad_visits = port_vessel_with_label.groupby('port.name')['label'].sum().reset_index()
share_of_bad_visits = port_vessel_with_label.groupby('port.name')['label'].mean().reset_index()
# ports_summary = port_visits_known_ships.merge(share_of_loitering, on='port.name', how='left')
ports_summary = share_of_loitering.merge(number_of_bad_visits, on='port.name', how='left')
ports_summary = ports_summary.merge(share_of_bad_visits, on='port.name', how='left', suffixes=('_absolute_count', '_avg'))

# %%
ports_summary.sort_values('label_absolute_count', ascending=False).head(10)
# Out:
#            port.name  share_of_loitering  label_absolute_count  label_avg
# 480            BUSAN            0.849673                   692   0.837772
# 1963       SINGAPORE            0.915148                   550   0.963222
# 1552     PANAMA CITY            0.962655                   463   0.985106
# 562            COLON            0.964614                   450   0.984683
# 1189      LAS PALMAS            0.968288                   427   0.981609
# 2373        ZHOUSHAN            0.862232                   412   0.874735
# 1712  PUERTO BOLIVAR            0.982370                   311   1.000000
# 211          ABIDJAN            0.967003                   309   0.984076
# 700     EUROPA POINT            0.981289                   305   1.000000
# 2130            TEMA            0.962598                   300   0.980392

# %%
ports_summary.loc[ports_summary['label_absolute_count'] > 50].sort_values('share_of_loitering', ascending=False).head(10)
# Out:
#             port.name  share_of_loitering  label_absolute_count  label_avg
# 1714   PUERTO CALDERA            1.000000                    79        1.0
# 2368        ZEEBRUGGE            1.000000                    56        1.0
# 2204        UDDEVALLA            1.000000                    67        1.0
# 1303         MATARANI            0.999730                    65        1.0
# 1575  PEPILLO SALCEDO            0.999493                    81        1.0
# 1560       PARAMARIBO            0.999437                    66        1.0
# 1691       PORTSMOUTH            0.999185                    99        1.0
# 1883      SANTA MARTA            0.999138                   151        1.0
# 1353             MOIN            0.999051                   124        1.0
# 2099      TANCARVILLE            0.999014                    64        1.0

# %%
ports_summary['share_of_loitering'].mean()
# Out:
# 0.8281250779466328

# %%
ports_summary.loc[ports_summary['label_absolute_count'] > 50].sort_values('share_of_loitering', ascending=False).head(10)
# Out:
#             port.name  share_of_loitering  label_absolute_count  label_avg
# 1714   PUERTO CALDERA            1.000000                    79        1.0
# 2368        ZEEBRUGGE            1.000000                    56        1.0
# 2204        UDDEVALLA            1.000000                    67        1.0
# 1303         MATARANI            0.999730                    65        1.0
# 1575  PEPILLO SALCEDO            0.999493                    81        1.0
# 1560       PARAMARIBO            0.999437                    66        1.0
# 1691       PORTSMOUTH            0.999185                    99        1.0
# 1883      SANTA MARTA            0.999138                   151        1.0
# 1353             MOIN            0.999051                   124        1.0
# 2099      TANCARVILLE            0.999014                    64        1.0

# %%
len(ports_summary)
# Out:
# 2381

# %%
path = '/Users/sebastiandodt/OneDrive/Uni/Carnegie Mellon University/Modules/2022 Fall/Systems Project/Coding/90739-iuu-systems-project/port_evaluation/data/xlsx/gfw_data-v2.xlsx'
encounters = pd.read_excel(path, sheet_name='encounter')
encounters.head()
# Out:
#                              event_id event_type         event_start  \
# 0  bb36acd0ef06c619eeca0421d07ae5cd.1  encounter 2022-09-19 14:40:00
# 1  bb36acd0ef06c619eeca0421d07ae5cd.2  encounter 2022-09-19 14:40:00
# 2  bbc225900674c6a9c9d27fcfdb5600d9.1  encounter 2022-09-20 07:00:00
# 3  bbc225900674c6a9c9d27fcfdb5600d9.2  encounter 2022-09-20 07:00:00
# 4  30b519732007d7631f6f5fcc84049eee.2  encounter 2022-09-20 15:10:00
#
#             event_end  event_lat  event_lon  mpa   eez  \
# 0 2022-09-20 23:50:00    59.1361   164.0261  NaN  5690
# 1 2022-09-20 23:50:00    59.1361   164.0261  NaN  5690
# 2 2022-09-20 23:50:00    62.9143   179.4136  NaN  5690
# 3 2022-09-20 23:50:00    62.9143   179.4136  NaN  5690
# 4 2022-09-20 20:30:00    48.7694   140.6118  NaN  5690
#
#                       rfmo fao  ...  vessel1_type  vessel1_ssvid  \
# 0         IWC, ACAP, PICES  61  ...       fishing      273843020
# 1         IWC, PICES, ACAP  61  ...       carrier      273422240
# 2         IWC, PICES, ACAP  61  ...       fishing      273240400
# 3         PICES, ACAP, IWC  61  ...       carrier      273356290
# 4  IWC, ACAP, WCPFC, PICES  61  ...       fishing      273433540
#
#                               vessel2_id  vessel2_flag        vessel2_name  \
# 0  9e6a50d61-135a-cac1-5572-2064ec9b6184           RUS  KAPITAN KIRICHENKO
# 1  4858ea8e4-4822-cb70-d4a8-e536ee9bbedc           RUS      XX SYEZD VLKSM
# 2  f7ebe6fa3-3640-5c7f-17c2-83423449bb1e           RUS     VITALIY SHMYKOV
# 3  5ddb64d7e-ec33-e20d-7265-c717e3c59313           RUS              AHTIAR
# 4  489bfeb6d-d541-4161-1236-a1d70a89f03d           RUS             DRUZHBA
#
#    vessel2_type  vessel2_ssvid medianDistanceKilometers medianSpeedKnots  \
# 0       carrier      273422240                    0.061            0.090
# 1       fishing      273843020                    0.061            0.090
# 2       carrier      273356290                    0.049            0.015
# 3       fishing      273240400                    0.049            0.015
# 4       carrier      273895510                    0.022            0.691
#
#     encounter_type
# 0  fishing-carrier
# 1  carrier-fishing
# 2  fishing-carrier
# 3  carrier-fishing
# 4  fishing-carrier
#
# [5 rows x 30 columns]

# %%
encounters.loc[encounters['event_start'] >= '2022-01-01', :]
print("Number of encounters in 2022: ",len(encounters))
print("Number of different carriers active in 2022: ", len(encounters.loc[encounters['vessel1_type'] == 'carrier', 'vessel1_id'].unique()))
# Out:
# Number of encounters in 2022:  116400
# Number of different carriers active in 2022:  1066

# %%
sns.histplot(df.groupby('id')['loitering'].sum().reset_index().sort_values('loitering'),
    x='loitering', binwidth=100).set_yscale('log')
plt.title("Number of encounters")
# Out:
# Text(0.5, 1.0, 'Number of encounters')

# %%
sns.histplot(df.groupby('id')['loitering'].sum().reset_index().sort_values('loitering'),
    x='loitering')
# Out:
# <AxesSubplot: xlabel='loitering', ylabel='Count'>

# %%
df
# Out:
#       Unnamed: 0  name callsign firstTransmissionDate flag  geartype  \
# 0              0   888    UBXW8  2022-04-26T00:38:42Z  RUS       NaN
# 1              1   961    UBWO2  2016-07-18T07:48:42Z  RUS       NaN
# 2              2  1245     6LIW  2012-01-01T01:35:22Z  KOR       NaN
# 3              3  2522    3EMD9  2020-01-23T04:49:28Z  PAN       NaN
# 4              4  4337     UERQ  2012-01-29T00:53:34Z  RUS       NaN
# ...          ...   ...      ...                   ...  ...       ...
# 4588        4588  4133      NaN  2012-01-01T13:00:52Z  BHS       NaN
# 4589        4589  3272      NaN  2012-01-01T02:15:49Z  BHS       NaN
# 4590        4590  1997      NaN  2012-01-01T02:21:56Z  RUS       NaN
# 4591        4591  4513      NaN  2012-01-01T00:51:40Z  USA       NaN
# 4592        4592  3969      NaN  2012-01-01T00:23:32Z  BHS       NaN
#
#                                          id        imo  lastTransmissionDate  \
# 0     98bc368ac-c787-4a19-057e-5ba50cfefd32  8800224.0  2022-09-23T23:59:59Z
# 1     c5924375e-e60f-f108-7584-35babc14a1cf  8860468.0  2022-09-23T23:59:59Z
# 2     4e3401e92-242e-6104-da37-56b33f3aa7b2  9012331.0  2022-09-23T23:59:59Z
# 3     221ffdcdc-c54a-56ed-47c2-32b6e2f59a2f  8911102.0  2022-09-23T23:59:59Z
# 4     919330d08-8bf1-b971-02d3-e3c022b17802  8516639.0  2022-09-23T23:59:59Z
# ...                                     ...        ...                   ...
# 4588  35b5d68f3-3c9f-46ea-2dd6-3ba4567ed3f5        NaN  2012-01-01T14:39:09Z
# 4589  f4197ad44-43f8-3d10-de11-f49fbc13d5e2        NaN  2012-01-01T14:25:29Z
# 4590  8c2904bf9-9401-1aae-9260-34211082b4e9        NaN  2012-01-01T05:33:57Z
# 4591  16a8eea04-40d5-79dd-a2fd-9ee2b293ead3        NaN  2012-01-01T04:06:28Z
# 4592  a5a1867f1-1301-9237-5665-b3d2e90bc359        NaN  2012-01-01T04:02:27Z
#
#            mmsi  ...  posCount       shipname source vesselType  \
# 0     273294090  ...     69599   FRIO NAVARIN    AIS    Carrier
# 1     273398570  ...   1215699          POMOR    AIS    Carrier
# 2     441043000  ...   4051995       AGNES 83    AIS    Carrier
# 3     356155000  ...   1799880  TRITON REEFER    AIS    Carrier
# 4     273312860  ...    945053      GARMONIYA    AIS    Carrier
# ...         ...  ...       ...            ...    ...        ...
# 4588  311126000  ...         2            NaN    AIS    Carrier
# 4589  311664000  ...        53            NaN    AIS    Carrier
# 4590  273316080  ...         2            NaN    AIS    Carrier
# 4591  366577000  ...         9            NaN    AIS    Carrier
# 4592  309644000  ...         7            NaN    AIS    Carrier
#
#                                                   years  \
# 0                                                  2022
# 1              2016, 2017, 2018, 2019, 2020, 2021, 2022
# 2                                                  2019
# 3                                      2020, 2021, 2022
# 4     2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019...
# ...                                                 ...
# 4588                                               2012
# 4589                                               2012
# 4590                                               2012
# 4591                                               2012
# 4592                                               2012
#
#                                       dataset score  encounter  loitering  \
# 0     public-global-carrier-vessels:v20201001     1          8          5
# 1     public-global-carrier-vessels:v20201001     1        139        486
# 2     public-global-carrier-vessels:v20201001     1         12       2962
# 3     public-global-carrier-vessels:v20201001     1        227        404
# 4     public-global-carrier-vessels:v20201001     1        191        574
# ...                                       ...   ...        ...        ...
# 4588  public-global-carrier-vessels:v20201001     1          0          0
# 4589  public-global-carrier-vessels:v20201001     1          0          0
# 4590  public-global-carrier-vessels:v20201001     1          0          0
# 4591  public-global-carrier-vessels:v20201001     1          0          0
# 4592  public-global-carrier-vessels:v20201001     1          0          0
#
#       label
# 0         0
# 1         1
# 2         1
# 3         0
# 4         1
# ...     ...
# 4588      0
# 4589      0
# 4590      0
# 4591      0
# 4592      0
#
# [4593 rows x 21 columns]
